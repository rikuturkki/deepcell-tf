# %%
### Import dependencies

import numpy as np
import os
import matplotlib.pyplot as plt

# %%
### Set global variables

PATH_TO_MODELS_SAMIR = '/data/models/tissues/mibi/samir'
PATH_TO_MODELS_FULL = '/data/models/tissues/mibi/mibi_full'

# %%
#hist0 = np.load(os.path.join(PATH_TO_MODELS_SAMIR, '2018-09-13_mibi_31x31_31chanlib8__channels_last_sample__0.npz'))
#hist1 = np.load(os.path.join(PATH_TO_MODELS_FULL, '2018-09-13_mibi_31x31_r36_med8_normStd_lib8_re6_class_ITONE_channels_last_sample__0.npz'))
#hist2 = np.load(os.path.join(PATH_TO_MODELS_FULL, '2018-09-13_mibi_31x31_r36_med8_normStd_lib8_re6_class_ITTWO_channels_last_sample__0.npz'))

hist_stromal = np.load(os.path.join(PATH_TO_MODELS_SAMIR, '2018-10-02_mibi_31x31_stromal__channels_last_sample__0.npz'))
hist_stromal = np.load(os.path.join(PATH_TO_MODELS_FULL, '2018-10-08_mibi_31x31_CORE100_test1_channels_last_sample__0.npz'))

# %%
#datapoints0 = hist0['loss_history'][()]
#datapoints1 = hist1['loss_history'][()]
#datapoints2 = hist2['loss_history'][()]

datapoints_stromal = hist_stromal['loss_history'][()]

# %%
print(np.asarray(datapoints_stromal['val_acc']).max())
print(np.asarray(datapoints_stromal['acc']).max())
# Out:
# 0.9120476752333289
# 0.9069836621927261

# %%
plt.figure(figsize=(15,10))
plt.plot(datapoints_stromal['acc'])
plt.plot(datapoints_stromal['val_acc'])
#plt.plot(datapoints_stromal['loss'])
#plt.plot(datapoints_stromal['val_loss'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize=(15,10))
plt.plot(datapoints2['acc'])
plt.plot(datapoints2['val_acc'])
plt.plot(datapoints2['loss'])
plt.plot(datapoints['val_loss'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
print(np.asarray(datapoints1['val_acc']).max())
print(np.asarray(datapoints1['acc']).max())
print(np.asarray(datapoints1['val_loss']).min())
print(np.asarray(datapoints2['val_acc']).max())
print(np.asarray(datapoints2['acc']).max())
print(np.asarray(datapoints2['val_loss']).min())
# Out:
# 0.9403022529532833
# 0.9599511855988222
# 0.09328487135832221
# 0.9441055097013293
# 0.9602067827108537
# 0.08598290582796375
